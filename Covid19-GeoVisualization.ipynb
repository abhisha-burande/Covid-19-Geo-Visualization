# %% [markdown]
# # <center>Python World Map Geovisualization Dashboard using Covid Data

# %% [markdown]
# ### Import Libraries

# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Access Data via API

# %%
conn = http.client.HTTPSConnection("api.covid19api.com")
payload = ''
headers = {}
conn.request("GET", "/summary", payload, headers)
res = conn.getresponse()
data = res.read().decode('UTF-8')

# %% [markdown]
# ### Convert Data to JSON

# %%
covid1= json.loads(data)
covid1
# Out:
# {'Message': '',
#  'Global': {'NewConfirmed': 237666,
#   'TotalConfirmed': 33072057,
#   'NewDeaths': 3591,
#   'TotalDeaths': 997669,
#   'NewRecovered': 210161,
#   'TotalRecovered': 22921374},
#  'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 39227,
#    'NewDeaths': 0,
#    'TotalDeaths': 1453,
#    'NewRecovered': 7,
#    'TotalRecovered': 32642,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 106,
#    'TotalConfirmed': 13259,
#    'NewDeaths': 2,
#    'TotalDeaths': 377,
#    'NewRecovered': 0,
#    'TotalRecovered': 7397,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 153,
#    'TotalConfirmed': 51067,
#    'NewDeaths': 3,
#    'TotalDeaths': 1714,
#    'NewRecovered': 104,
#    'TotalRecovered': 35860,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1836,
#    'NewDeaths': 0,
#    'TotalDeaths': 53,
#    'NewRecovered': 0,
#    'TotalRecovered': 1263,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 46,
#    'TotalConfirmed': 4718,
#    'NewDeaths': 3,
#    'TotalDeaths': 174,
#    'NewRecovered': 68,
#    'TotalRecovered': 1707,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 101,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 92,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 8841,
#    'TotalConfirmed': 711325,
#    'NewDeaths': 206,
#    'TotalDeaths': 15749,
#    'NewRecovered': 9446,
#    'TotalRecovered': 565935,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 328,
#    'TotalConfirmed': 49400,
#    'NewDeaths': 3,
#    'TotalDeaths': 951,
#    'NewRecovered': 37,
#    'TotalRecovered': 43613,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 27044,
#    'NewDeaths': 3,
#    'TotalDeaths': 875,
#    'NewRecovered': 60,
#    'TotalRecovered': 24631,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 662,
#    'TotalConfirmed': 42876,
#    'NewDeaths': 0,
#    'TotalDeaths': 787,
#    'NewRecovered': 435,
#    'TotalRecovered': 33589,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 128,
#    'TotalConfirmed': 40023,
#    'NewDeaths': 1,
#    'TotalDeaths': 586,
#    'NewRecovered': 132,
#    'TotalRecovered': 37655,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 3838,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 6,
#    'TotalRecovered': 2005,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 586,
#    'TotalConfirmed': 69361,
#    'NewDeaths': 3,
#    'TotalDeaths': 242,
#    'NewRecovered': 635,
#    'TotalRecovered': 62887,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 1275,
#    'TotalConfirmed': 359148,
#    'NewDeaths': 32,
#    'TotalDeaths': 5161,
#    'NewRecovered': 1714,
#    'TotalRecovered': 270491,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 190,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 178,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 320,
#    'TotalConfirmed': 77609,
#    'NewDeaths': 5,
#    'TotalDeaths': 818,
#    'NewRecovered': 74,
#    'TotalRecovered': 74120,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 1376,
#    'TotalConfirmed': 114179,
#    'NewDeaths': 6,
#    'TotalDeaths': 9980,
#    'NewRecovered': 29,
#    'TotalRecovered': 19275,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1825,
#    'NewDeaths': 0,
#    'TotalDeaths': 24,
#    'NewRecovered': 0,
#    'TotalRecovered': 1165,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 2340,
#    'NewDeaths': 0,
#    'TotalDeaths': 40,
#    'NewRecovered': 0,
#    'TotalRecovered': 1960,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 273,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 5,
#    'TotalRecovered': 210,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 309,
#    'TotalConfirmed': 133901,
#    'NewDeaths': 30,
#    'TotalDeaths': 7858,
#    'NewRecovered': 385,
#    'TotalRecovered': 93791,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 123,
#    'TotalConfirmed': 26920,
#    'NewDeaths': 2,
#    'TotalDeaths': 822,
#    'NewRecovered': 0,
#    'TotalRecovered': 19746,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2921,
#    'NewDeaths': 0,
#    'TotalDeaths': 16,
#    'NewRecovered': 0,
#    'TotalRecovered': 701,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 14318,
#    'TotalConfirmed': 4732309,
#    'NewDeaths': 335,
#    'TotalDeaths': 141741,
#    'NewRecovered': 19404,
#    'TotalRecovered': 4172711,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 146,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 142,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 20055,
#    'NewDeaths': 7,
#    'TotalDeaths': 796,
#    'NewRecovered': 16,
#    'TotalRecovered': 14176,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 2008,
#    'NewDeaths': 0,
#    'TotalDeaths': 56,
#    'NewRecovered': 12,
#    'TotalRecovered': 1276,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 485,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 472,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 276,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 275,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20735,
#    'NewDeaths': 0,
#    'TotalDeaths': 418,
#    'NewRecovered': 0,
#    'TotalRecovered': 19440,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 1658,
#    'TotalConfirmed': 155415,
#    'NewDeaths': 5,
#    'TotalDeaths': 9317,
#    'NewRecovered': 951,
#    'TotalRecovered': 133204,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 70,
#    'TotalConfirmed': 5771,
#    'NewDeaths': 1,
#    'TotalDeaths': 57,
#    'NewRecovered': 13,
#    'TotalRecovered': 5031,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4806,
#    'NewDeaths': 0,
#    'TotalDeaths': 62,
#    'NewRecovered': 0,
#    'TotalRecovered': 1840,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1178,
#    'NewDeaths': 1,
#    'TotalDeaths': 84,
#    'NewRecovered': 0,
#    'TotalRecovered': 1005,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1922,
#    'TotalConfirmed': 457901,
#    'NewDeaths': 50,
#    'TotalDeaths': 12641,
#    'NewRecovered': 1445,
#    'TotalRecovered': 431704,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 27,
#    'TotalConfirmed': 90483,
#    'NewDeaths': 0,
#    'TotalDeaths': 4739,
#    'NewRecovered': 21,
#    'TotalRecovered': 85381,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 7018,
#    'TotalConfirmed': 813056,
#    'NewDeaths': 192,
#    'TotalDeaths': 25488,
#    'NewRecovered': 11360,
#    'TotalRecovered': 711472,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 478,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 458,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 5008,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 0,
#    'TotalRecovered': 3887,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 10612,
#    'NewDeaths': 0,
#    'TotalDeaths': 271,
#    'NewRecovered': 0,
#    'TotalRecovered': 10093,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 72049,
#    'NewDeaths': 0,
#    'TotalDeaths': 828,
#    'NewRecovered': 0,
#    'TotalRecovered': 27760,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 190,
#    'TotalConfirmed': 16197,
#    'NewDeaths': 3,
#    'TotalDeaths': 272,
#    'NewRecovered': 204,
#    'TotalRecovered': 14609,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 45,
#    'TotalConfirmed': 5457,
#    'NewDeaths': 2,
#    'TotalDeaths': 122,
#    'NewRecovered': 19,
#    'TotalRecovered': 4751,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 1696,
#    'NewDeaths': 0,
#    'TotalDeaths': 22,
#    'NewRecovered': 0,
#    'TotalRecovered': 1369,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 1303,
#    'TotalConfirmed': 64597,
#    'NewDeaths': 15,
#    'TotalDeaths': 606,
#    'NewRecovered': 332,
#    'TotalRecovered': 31268,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 19629,
#    'NewDeaths': 0,
#    'TotalDeaths': 120,
#    'NewRecovered': 41,
#    'TotalRecovered': 19163,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 424,
#    'TotalConfirmed': 27111,
#    'NewDeaths': 1,
#    'TotalDeaths': 649,
#    'NewRecovered': 306,
#    'TotalRecovered': 20087,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5409,
#    'NewDeaths': 0,
#    'TotalDeaths': 61,
#    'NewRecovered': 0,
#    'TotalRecovered': 5340,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 30,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 6,
#    'TotalRecovered': 24,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 429,
#    'TotalConfirmed': 111386,
#    'NewDeaths': 2,
#    'TotalDeaths': 2095,
#    'NewRecovered': 745,
#    'TotalRecovered': 85965,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 766,
#    'TotalConfirmed': 134747,
#    'NewDeaths': 6,
#    'TotalDeaths': 11279,
#    'NewRecovered': 9444,
#    'TotalRecovered': 112296,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 104,
#    'TotalConfirmed': 102840,
#    'NewDeaths': 14,
#    'TotalDeaths': 5883,
#    'NewRecovered': 706,
#    'TotalRecovered': 95080,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 215,
#    'TotalConfirmed': 28630,
#    'NewDeaths': 0,
#    'TotalDeaths': 826,
#    'NewRecovered': 236,
#    'TotalRecovered': 22879,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5028,
#    'NewDeaths': 0,
#    'TotalDeaths': 83,
#    'NewRecovered': 0,
#    'TotalRecovered': 4740,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 375,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 341,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 3200,
#    'NewDeaths': 0,
#    'TotalDeaths': 64,
#    'NewRecovered': 7,
#    'TotalRecovered': 2506,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 632,
#    'TotalConfirmed': 73332,
#    'NewDeaths': 5,
#    'TotalDeaths': 1170,
#    'NewRecovered': 334,
#    'TotalRecovered': 30363,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 28,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 105,
#    'TotalConfirmed': 9682,
#    'NewDeaths': 0,
#    'TotalDeaths': 343,
#    'NewRecovered': 0,
#    'TotalRecovered': 7850,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 552473,
#    'NewDeaths': 0,
#    'TotalDeaths': 31675,
#    'NewRecovered': 0,
#    'TotalRecovered': 96937,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8728,
#    'NewDeaths': 0,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 7934,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 3569,
#    'NewDeaths': 1,
#    'TotalDeaths': 111,
#    'NewRecovered': 127,
#    'TotalRecovered': 2161,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 294,
#    'TotalConfirmed': 5254,
#    'NewDeaths': 0,
#    'TotalDeaths': 28,
#    'NewRecovered': 87,
#    'TotalRecovered': 1906,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 1313,
#    'TotalConfirmed': 286339,
#    'NewDeaths': 5,
#    'TotalDeaths': 9464,
#    'NewRecovered': 762,
#    'TotalRecovered': 250866,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 165,
#    'TotalConfirmed': 46387,
#    'NewDeaths': 0,
#    'TotalDeaths': 299,
#    'NewRecovered': 201,
#    'TotalRecovered': 45618,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 216,
#    'TotalConfirmed': 17444,
#    'NewDeaths': 3,
#    'TotalDeaths': 379,
#    'NewRecovered': 0,
#    'TotalRecovered': 1347,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 390,
#    'TotalConfirmed': 90092,
#    'NewDeaths': 16,
#    'TotalDeaths': 3229,
#    'NewRecovered': 414,
#    'TotalRecovered': 78698,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 68,
#    'TotalConfirmed': 10580,
#    'NewDeaths': 1,
#    'TotalDeaths': 66,
#    'NewRecovered': 56,
#    'TotalRecovered': 9892,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2324,
#    'NewDeaths': 0,
#    'TotalDeaths': 39,
#    'NewRecovered': 0,
#    'TotalRecovered': 1549,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 47,
#    'TotalConfirmed': 2772,
#    'NewDeaths': 2,
#    'TotalDeaths': 76,
#    'NewRecovered': 29,
#    'TotalRecovered': 1564,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 8740,
#    'NewDeaths': 0,
#    'TotalDeaths': 227,
#    'NewRecovered': 137,
#    'TotalRecovered': 6688,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 74548,
#    'NewDeaths': 0,
#    'TotalDeaths': 2288,
#    'NewRecovered': 0,
#    'TotalRecovered': 26088,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 937,
#    'TotalConfirmed': 24014,
#    'NewDeaths': 6,
#    'TotalDeaths': 736,
#    'NewRecovered': 42,
#    'TotalRecovered': 5141,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 2623,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 2,
#    'TotalRecovered': 2158,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 82170,
#    'TotalConfirmed': 6074702,
#    'NewDeaths': 1039,
#    'TotalDeaths': 95542,
#    'NewRecovered': 74893,
#    'TotalRecovered': 5016520,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 3874,
#    'TotalConfirmed': 275213,
#    'NewDeaths': 78,
#    'TotalDeaths': 10386,
#    'NewRecovered': 3611,
#    'TotalRecovered': 203014,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 3362,
#    'TotalConfirmed': 446448,
#    'NewDeaths': 195,
#    'TotalDeaths': 25589,
#    'NewRecovered': 2119,
#    'TotalRecovered': 374170,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 3481,
#    'TotalConfirmed': 349450,
#    'NewDeaths': 55,
#    'TotalDeaths': 8990,
#    'NewRecovered': 3755,
#    'TotalRecovered': 280673,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 430,
#    'TotalConfirmed': 34990,
#    'NewDeaths': 0,
#    'TotalDeaths': 1802,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 3926,
#    'TotalConfirmed': 231026,
#    'NewDeaths': 25,
#    'TotalDeaths': 1466,
#    'NewRecovered': 2394,
#    'TotalRecovered': 159931,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 1766,
#    'TotalConfirmed': 309870,
#    'NewDeaths': 17,
#    'TotalDeaths': 35835,
#    'NewRecovered': 724,
#    'TotalRecovered': 224417,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 163,
#    'TotalConfirmed': 6017,
#    'NewDeaths': 1,
#    'TotalDeaths': 89,
#    'NewRecovered': 82,
#    'TotalRecovered': 1706,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 483,
#    'TotalConfirmed': 82186,
#    'NewDeaths': 2,
#    'TotalDeaths': 1549,
#    'NewRecovered': 0,
#    'TotalRecovered': 73677,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 431,
#    'TotalConfirmed': 8492,
#    'NewDeaths': 2,
#    'TotalDeaths': 45,
#    'NewRecovered': 91,
#    'TotalRecovered': 4222,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 107775,
#    'NewDeaths': 0,
#    'TotalDeaths': 1699,
#    'NewRecovered': 70,
#    'TotalRecovered': 102736,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 244,
#    'TotalConfirmed': 38115,
#    'NewDeaths': 2,
#    'TotalDeaths': 691,
#    'NewRecovered': 40,
#    'TotalRecovered': 24621,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 23661,
#    'NewDeaths': 5,
#    'TotalDeaths': 406,
#    'NewRecovered': 44,
#    'TotalRecovered': 21292,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 345,
#    'TotalConfirmed': 103544,
#    'NewDeaths': 4,
#    'TotalDeaths': 601,
#    'NewRecovered': 718,
#    'TotalRecovered': 94929,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 161,
#    'TotalConfirmed': 46251,
#    'NewDeaths': 0,
#    'TotalDeaths': 1063,
#    'NewRecovered': 151,
#    'TotalRecovered': 42453,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 22,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 1676,
#    'NewDeaths': 0,
#    'TotalDeaths': 36,
#    'NewRecovered': 0,
#    'TotalRecovered': 1304,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 1012,
#    'TotalConfirmed': 36254,
#    'NewDeaths': 7,
#    'TotalDeaths': 347,
#    'NewRecovered': 655,
#    'TotalRecovered': 16089,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1558,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 0,
#    'TotalRecovered': 797,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1339,
#    'NewDeaths': 0,
#    'TotalDeaths': 82,
#    'NewRecovered': 0,
#    'TotalRecovered': 1221,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 536,
#    'TotalConfirmed': 32364,
#    'NewDeaths': 21,
#    'TotalDeaths': 520,
#    'NewRecovered': 296,
#    'TotalRecovered': 18128,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 117,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 110,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 90,
#    'TotalConfirmed': 4385,
#    'NewDeaths': 2,
#    'TotalDeaths': 91,
#    'NewRecovered': 8,
#    'TotalRecovered': 2327,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8233,
#    'NewDeaths': 0,
#    'TotalDeaths': 124,
#    'NewRecovered': 0,
#    'TotalRecovered': 6976,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 146,
#    'TotalConfirmed': 17629,
#    'NewDeaths': 3,
#    'TotalDeaths': 725,
#    'NewRecovered': 65,
#    'TotalRecovered': 14581,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 28,
#    'TotalConfirmed': 16285,
#    'NewDeaths': 0,
#    'TotalDeaths': 229,
#    'NewRecovered': 0,
#    'TotalRecovered': 14922,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 5768,
#    'NewDeaths': 0,
#    'TotalDeaths': 179,
#    'NewRecovered': 21,
#    'TotalRecovered': 4206,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 150,
#    'TotalConfirmed': 10919,
#    'NewDeaths': 1,
#    'TotalDeaths': 134,
#    'NewRecovered': 50,
#    'TotalRecovered': 9835,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 53,
#    'TotalConfirmed': 10098,
#    'NewDeaths': 0,
#    'TotalDeaths': 34,
#    'NewRecovered': 93,
#    'TotalRecovered': 8847,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 3086,
#    'NewDeaths': 0,
#    'TotalDeaths': 130,
#    'NewRecovered': 10,
#    'TotalRecovered': 2420,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 21,
#    'TotalConfirmed': 2979,
#    'NewDeaths': 0,
#    'TotalDeaths': 31,
#    'NewRecovered': 54,
#    'TotalRecovered': 2358,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 7464,
#    'NewDeaths': 0,
#    'TotalDeaths': 161,
#    'NewRecovered': 0,
#    'TotalRecovered': 7070,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 367,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 343,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 3886,
#    'TotalConfirmed': 730317,
#    'NewDeaths': 187,
#    'TotalDeaths': 76430,
#    'NewRecovered': 4335,
#    'TotalRecovered': 616696,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 341,
#    'TotalConfirmed': 50875,
#    'NewDeaths': 8,
#    'TotalDeaths': 1287,
#    'NewRecovered': 402,
#    'TotalRecovered': 37842,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 210,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 169,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 313,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 305,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 116,
#    'TotalConfirmed': 10313,
#    'NewDeaths': 0,
#    'TotalDeaths': 158,
#    'NewRecovered': 88,
#    'TotalRecovered': 6456,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 2444,
#    'TotalConfirmed': 117685,
#    'NewDeaths': 28,
#    'TotalDeaths': 2069,
#    'NewRecovered': 1441,
#    'TotalRecovered': 95591,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 226,
#    'TotalConfirmed': 7983,
#    'NewDeaths': 4,
#    'TotalDeaths': 58,
#    'NewRecovered': 38,
#    'TotalRecovered': 4807,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 743,
#    'TotalConfirmed': 10734,
#    'NewDeaths': 28,
#    'TotalDeaths': 226,
#    'NewRecovered': 181,
#    'TotalRecovered': 2862,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 115,
#    'TotalConfirmed': 11033,
#    'NewDeaths': 0,
#    'TotalDeaths': 120,
#    'NewRecovered': 27,
#    'TotalRecovered': 8776,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 1573,
#    'TotalConfirmed': 73394,
#    'NewDeaths': 10,
#    'TotalDeaths': 477,
#    'NewRecovered': 885,
#    'TotalRecovered': 53898,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 108631,
#    'NewDeaths': 0,
#    'TotalDeaths': 6366,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1833,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 4,
#    'TotalRecovered': 1753,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5073,
#    'NewDeaths': 0,
#    'TotalDeaths': 149,
#    'NewRecovered': 0,
#    'TotalRecovered': 2913,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 1196,
#    'NewDeaths': 0,
#    'TotalDeaths': 69,
#    'NewRecovered': 0,
#    'TotalRecovered': 1107,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 126,
#    'TotalConfirmed': 58324,
#    'NewDeaths': 2,
#    'TotalDeaths': 1108,
#    'NewRecovered': 72,
#    'TotalRecovered': 49794,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 71,
#    'TotalConfirmed': 13698,
#    'NewDeaths': 0,
#    'TotalDeaths': 270,
#    'NewRecovered': 0,
#    'TotalRecovered': 11190,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 1543,
#    'TotalConfirmed': 97450,
#    'NewDeaths': 24,
#    'TotalDeaths': 909,
#    'NewRecovered': 1036,
#    'TotalRecovered': 87801,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 566,
#    'TotalConfirmed': 310841,
#    'NewDeaths': 9,
#    'TotalDeaths': 6466,
#    'NewRecovered': 409,
#    'TotalRecovered': 296022,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 450,
#    'TotalConfirmed': 38703,
#    'NewDeaths': 6,
#    'TotalDeaths': 291,
#    'NewRecovered': 1364,
#    'TotalRecovered': 29068,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 447,
#    'TotalConfirmed': 110555,
#    'NewDeaths': 17,
#    'TotalDeaths': 2340,
#    'NewRecovered': 419,
#    'TotalRecovered': 87215,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 532,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 516,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 762,
#    'TotalConfirmed': 38684,
#    'NewDeaths': 21,
#    'TotalDeaths': 803,
#    'NewRecovered': 662,
#    'TotalRecovered': 22419,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 5558,
#    'TotalConfirmed': 800142,
#    'NewDeaths': 105,
#    'TotalDeaths': 32142,
#    'NewRecovered': 0,
#    'TotalRecovered': 657836,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 2970,
#    'TotalConfirmed': 304226,
#    'NewDeaths': 60,
#    'TotalDeaths': 5344,
#    'NewRecovered': 19604,
#    'TotalRecovered': 252510,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 1350,
#    'TotalConfirmed': 87330,
#    'NewDeaths': 8,
#    'TotalDeaths': 2432,
#    'NewRecovered': 578,
#    'TotalRecovered': 67904,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 665,
#    'TotalConfirmed': 73604,
#    'NewDeaths': 9,
#    'TotalDeaths': 1953,
#    'NewRecovered': 267,
#    'TotalRecovered': 47647,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 234,
#    'TotalConfirmed': 125084,
#    'NewDeaths': 0,
#    'TotalDeaths': 214,
#    'NewRecovered': 257,
#    'TotalRecovered': 121995,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12683,
#    'NewDeaths': 0,
#    'TotalDeaths': 488,
#    'NewRecovered': 0,
#    'TotalRecovered': 8788,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 1438,
#    'TotalConfirmed': 122673,
#    'NewDeaths': 31,
#    'TotalDeaths': 4718,
#    'NewRecovered': 1053,
#    'TotalRecovered': 98607,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 7764,
#    'TotalConfirmed': 1146273,
#    'NewDeaths': 99,
#    'TotalDeaths': 20239,
#    'NewRecovered': 3040,
#    'TotalRecovered': 939921,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 4820,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 8,
#    'TotalRecovered': 3099,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 17,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 64,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 727,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 676,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 911,
#    'NewDeaths': 0,
#    'TotalDeaths': 15,
#    'NewRecovered': 0,
#    'TotalRecovered': 883,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 403,
#    'TotalConfirmed': 333193,
#    'NewDeaths': 28,
#    'TotalDeaths': 4683,
#    'NewRecovered': 600,
#    'TotalRecovered': 317005,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 14909,
#    'NewDeaths': 2,
#    'TotalDeaths': 308,
#    'NewRecovered': 85,
#    'TotalRecovered': 12113,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 72,
#    'TotalConfirmed': 33384,
#    'NewDeaths': 1,
#    'TotalDeaths': 747,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 143,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 140,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 2215,
#    'NewDeaths': 0,
#    'TotalDeaths': 72,
#    'NewRecovered': 2,
#    'TotalRecovered': 1681,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 57700,
#    'NewDeaths': 0,
#    'TotalDeaths': 27,
#    'NewRecovered': 8,
#    'TotalRecovered': 57367,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 478,
#    'TotalConfirmed': 9078,
#    'NewDeaths': 0,
#    'TotalDeaths': 44,
#    'NewRecovered': 80,
#    'TotalRecovered': 4178,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 159,
#    'TotalConfirmed': 5350,
#    'NewDeaths': 1,
#    'TotalDeaths': 147,
#    'NewRecovered': 98,
#    'TotalRecovered': 3555,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3588,
#    'NewDeaths': 0,
#    'TotalDeaths': 99,
#    'NewRecovered': 3,
#    'TotalRecovered': 2946,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 1268,
#    'TotalConfirmed': 670766,
#    'NewDeaths': 22,
#    'TotalDeaths': 16398,
#    'NewRecovered': 1903,
#    'TotalRecovered': 603721,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 2686,
#    'NewDeaths': 0,
#    'TotalDeaths': 49,
#    'NewRecovered': 0,
#    'TotalRecovered': 1290,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 716481,
#    'NewDeaths': 0,
#    'TotalDeaths': 31232,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 3360,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 22,
#    'TotalRecovered': 3208,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13606,
#    'NewDeaths': 0,
#    'TotalDeaths': 836,
#    'NewRecovered': 0,
#    'TotalRecovered': 6764,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 4835,
#    'NewDeaths': 0,
#    'TotalDeaths': 102,
#    'NewRecovered': 41,
#    'TotalRecovered': 4661,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 5431,
#    'NewDeaths': 0,
#    'TotalDeaths': 108,
#    'NewRecovered': 19,
#    'TotalRecovered': 4821,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 90923,
#    'NewDeaths': 0,
#    'TotalDeaths': 5880,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 51864,
#    'NewDeaths': 0,
#    'TotalDeaths': 2064,
#    'NewRecovered': 100,
#    'TotalRecovered': 42700,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 34,
#    'TotalConfirmed': 4072,
#    'NewDeaths': 4,
#    'TotalDeaths': 192,
#    'NewRecovered': 14,
#    'TotalRecovered': 1062,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 510,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 480,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 9646,
#    'NewDeaths': 0,
#    'TotalDeaths': 75,
#    'NewRecovered': 45,
#    'TotalRecovered': 8430,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3523,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 0,
#    'TotalRecovered': 3367,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 1743,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 11,
#    'TotalRecovered': 1330,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 4362,
#    'NewDeaths': 1,
#    'TotalDeaths': 71,
#    'NewRecovered': 49,
#    'TotalRecovered': 2234,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 1722,
#    'TotalConfirmed': 16114,
#    'NewDeaths': 23,
#    'TotalDeaths': 214,
#    'NewRecovered': 0,
#    'TotalRecovered': 5032,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 1467,
#    'TotalConfirmed': 314433,
#    'NewDeaths': 68,
#    'TotalDeaths': 7997,
#    'NewRecovered': 1116,
#    'TotalRecovered': 275630,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 166,
#    'TotalConfirmed': 7530,
#    'NewDeaths': 2,
#    'TotalDeaths': 73,
#    'NewRecovered': 0,
#    'TotalRecovered': 3647,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 3233,
#    'TotalConfirmed': 203799,
#    'NewDeaths': 56,
#    'TotalDeaths': 4044,
#    'NewRecovered': 1037,
#    'TotalRecovered': 91179,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 851,
#    'TotalConfirmed': 91469,
#    'NewDeaths': 1,
#    'TotalDeaths': 412,
#    'NewRecovered': 868,
#    'TotalRecovered': 80544,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 5700,
#    'TotalConfirmed': 437517,
#    'NewDeaths': 17,
#    'TotalDeaths': 42077,
#    'NewRecovered': 6,
#    'TotalRecovered': 2339,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 36919,
#    'TotalConfirmed': 7115008,
#    'NewDeaths': 266,
#    'TotalDeaths': 204756,
#    'NewRecovered': 15821,
#    'TotalRecovered': 2766280,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 2008,
#    'NewDeaths': 0,
#    'TotalDeaths': 47,
#    'NewRecovered': 12,
#    'TotalRecovered': 1728,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 501,
#    'TotalConfirmed': 55320,
#    'NewDeaths': 6,
#    'TotalDeaths': 458,
#    'NewRecovered': 507,
#    'TotalRecovered': 51829,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 751,
#    'TotalConfirmed': 72691,
#    'NewDeaths': 6,
#    'TotalDeaths': 606,
#    'NewRecovered': 899,
#    'TotalRecovered': 62427,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 1074,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 0,
#    'TotalRecovered': 999,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2030,
#    'NewDeaths': 0,
#    'TotalDeaths': 587,
#    'NewRecovered': 6,
#    'TotalRecovered': 1266,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 14641,
#    'NewDeaths': 0,
#    'TotalDeaths': 332,
#    'NewRecovered': 57,
#    'TotalRecovered': 13784,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 7812,
#    'NewDeaths': 0,
#    'TotalDeaths': 227,
#    'NewRecovered': 39,
#    'TotalRecovered': 6106,
#    'Date': '2020-09-29T01:54:18Z',
#    'Premium': {}}],
#  'Date': '2020-09-29T01:54:18Z'}

# %% [markdown]
# ### Normalize Data

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            35           39227
# 1           Albania          AL         albania           106           13259
# 2           Algeria          DZ         algeria           153           51067
# 3           Andorra          AD         andorra             0            1836
# 4            Angola          AO          angola            46            4718
# ..              ...         ...             ...           ...             ...
# 183        Viet Nam          VN         vietnam             5            1074
# 184  Western Sahara          EH  western-sahara             0              10
# 185           Yemen          YE           yemen             0            2030
# 186          Zambia          ZM          zambia            29           14641
# 187        Zimbabwe          ZW        zimbabwe             9            7812
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            0         1453             7           32642
# 1            2          377             0            7397
# 2            3         1714           104           35860
# 3            0           53             0            1263
# 4            3          174            68            1707
# ..         ...          ...           ...             ...
# 183          0           35             0             999
# 184          0            1             0               8
# 185          0          587             6            1266
# 186          0          332            57           13784
# 187          0          227            39            6106
#
#                      Date
# 0    2020-09-29T01:54:18Z
# 1    2020-09-29T01:54:18Z
# 2    2020-09-29T01:54:18Z
# 3    2020-09-29T01:54:18Z
# 4    2020-09-29T01:54:18Z
# ..                    ...
# 183  2020-09-29T01:54:18Z
# 184  2020-09-29T01:54:18Z
# 185  2020-09-29T01:54:18Z
# 186  2020-09-29T01:54:18Z
# 187  2020-09-29T01:54:18Z
#
# [188 rows x 10 columns]

# %% [markdown]
# ### Convert to Pandas DataFrame

# %%
df = pd.DataFrame(covid1['Countries'])
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            35           39227
# 1           Albania          AL         albania           106           13259
# 2           Algeria          DZ         algeria           153           51067
# 3           Andorra          AD         andorra             0            1836
# 4            Angola          AO          angola            46            4718
# ..              ...         ...             ...           ...             ...
# 183        Viet Nam          VN         vietnam             5            1074
# 184  Western Sahara          EH  western-sahara             0              10
# 185           Yemen          YE           yemen             0            2030
# 186          Zambia          ZM          zambia            29           14641
# 187        Zimbabwe          ZW        zimbabwe             9            7812
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            0         1453             7           32642
# 1            2          377             0            7397
# 2            3         1714           104           35860
# 3            0           53             0            1263
# 4            3          174            68            1707
# ..         ...          ...           ...             ...
# 183          0           35             0             999
# 184          0            1             0               8
# 185          0          587             6            1266
# 186          0          332            57           13784
# 187          0          227            39            6106
#
#                      Date Premium
# 0    2020-09-29T01:54:18Z      {}
# 1    2020-09-29T01:54:18Z      {}
# 2    2020-09-29T01:54:18Z      {}
# 3    2020-09-29T01:54:18Z      {}
# 4    2020-09-29T01:54:18Z      {}
# ..                    ...     ...
# 183  2020-09-29T01:54:18Z      {}
# 184  2020-09-29T01:54:18Z      {}
# 185  2020-09-29T01:54:18Z      {}
# 186  2020-09-29T01:54:18Z      {}
# 187  2020-09-29T01:54:18Z      {}
#
# [188 rows x 11 columns]

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
covid2 = df.drop(columns =['CountryCode','Slug','Date','Premium'],axis=1)

# %% [markdown]
# ### Generate Base Map

# %%
m = folium.Map(tiles="Stamen Terrain", min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Geodata

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %% [markdown]
# ### Generate Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='COVID-19',
    data=covid2,
    columns=['Country', 'TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed Covid Cases',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Markers

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %%
coordinates = pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final= pd.merge(covid2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalConfirmed,point.TotalRecovered],
                        fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot, axis = 1)

m.fit_bounds(m.get_bounds())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Base Map

# %%
m1 = folium.Map(tiles='StamenToner', min_zoom=2)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %% [markdown]
# ### Generate Heat Map Layer

# %%
m1.add_child(HeatMap(zip(lat,lon,deaths),radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Marker

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalDeaths],
                        fill_color='#000000').add_to(m1)

covid_final.apply(plotDot, axis = 1)

m1.fit_bounds(m1.get_bounds())

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
